# %%
import pandas as pd
from pandas_profiling import ProfileReport
import matplotlib as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('C:/Users/zhang/Desktop/Stackoverflow_report/Data/survey_results_public.csv')

# %%
prof = ProfileReport(df, minimal=True)
prof.to_widgets()

# %%
#Q1: Does big company have more competitive salary?
Org_Comp_plt = sns.boxplot(x='OrgSize', y='CompTotal', data=df)
Org_Comp_plt.set_ylim([0, 3*1e5])
Org_Comp_plt.tick_params(axis='x', rotation=90)

# %%
#Q2: Doe high education worth the price?
Ed_Comp_plt = sns.boxplot(x='EdLevel', y='CompTotal', data=df)
Ed_Comp_plt.set_ylim([0, 2*1e5])
Ed_Comp_plt.tick_params(axis='x', rotation=90)

# %%
#Q3: Does stack overflow help if you actively contribute to the forum?
So_Part_plt = sns.boxplot(x='SOPartFreq', y='CompTotal', data=df)
So_Part_plt.set_ylim([0, 2*1e5])
So_Part_plt.tick_params(axis='x', rotation=90)

# %%
SO_Visit_plt = sns.countplot(data=df, x="SOVisitFreq")
SO_Visit_plt.tick_params(axis='x', rotation=90)
